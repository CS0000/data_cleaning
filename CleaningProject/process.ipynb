# %%
import pandas as pd
from pandas_profiling import ProfileReport
import numpy as np

# %%
raw_data = pd.read_csv('./raw_data/HF_fake_v1.csv',header=None, index_col=None,sep=',')

# %%
raw_data.head()
# Out:
#    0    1        2                         3         4                  5   \
# 0  ID  age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction
# 1  s1   75        0                       582         0                 20
# 2  s2   55        0                      7861         0                 38
# 3  s3   65        0                       146         0                 20
# 4  s4   50        1                       111         0                 20
#
#                     6                    7          8                 9   \
# 0  high_blood_pressure  high_blood_pressure  platelets  serum_creatinine
# 1                    1                  121     265000               1.9
# 2                    0                  154  263358.03               1.1
# 3                    0                  189     162000               1.3
# 4                    0                  206     210000               1.9
#
#              10   11       12    13           14
# 0  serum_sodium  sex  smoking  time  DEATH_EVENT
# 1           130    1        0     4            1
# 2           136    1        0     6            1
# 3           129    1        1     7            1
# 4           137    1        0     7            1
